# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3"

from transformers import AutoModelForCausalLM, AutoTokenizer
device = "cuda" # the device to load the model onto

model = AutoModelForCausalLM.from_pretrained("/storage1/fs1/yinjie.tang/Active/Shawn_Xiao/Qwen1.5-14B-Chat",
    device_map="auto", torch_dtype="auto"
)
tokenizer = AutoTokenizer.from_pretrained("/storage1/fs1/yinjie.tang/Active/Shawn_Xiao/Qwen1.5-14B-Chat")

#Qwen1.5-72B-Chat-GPTQ-Int4
#Qwen1.5-14B-Chat
# Out:
# Loading checkpoint shards:   0%|          | 0/38 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# pip install PyMuPDF
import pandas as pd
import os
import torch
import fitz

def read_pdf_and_split_into_chunks(pdf_path, chunk_size=1000):
    # Open the PDF file
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    doc.close()
    
    # Split text into chunks of `chunk_size` words
    words = text.split()
    chunks = [' '.join(words[i:i+chunk_size]) for i in range(0, len(words), chunk_size)]
    return chunks

def ask_questions(chunks, question, system_prompt):
    combined_response = []
    for chunk in chunks:
        prompt_text = question + " " + str(chunk)
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt_text}
        ]
        text = tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True
        )
        model_inputs = tokenizer([text], return_tensors="pt").to(device)
        
        generated_ids = model.generate(
            model_inputs.input_ids,
            max_new_tokens=5000
        )
        generated_ids = [
            output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
        ]
        
        response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
        combined_response.append(response)
    return " ".join(combined_response)

# Directory containing PDF files
pdf_directory = os.getcwd()
pdf_files = [f for f in os.listdir(pdf_directory) if f.endswith('.pdf')]

# Prepare DataFrame
df = pd.DataFrame(columns=['PDF Title', 'Combined Response'])

# Define your question and system prompt for question 2
questions = " "  # Placeholder for the actual question text if needed


system_prompts = "You are specialized for analyzing scientific paper abstracts, focusing on identifying entities causal relationships related to biological studies, such as performance, species, genes, methods of genetic engineering, enzymes, proteins, and bioprocess conditions (e.g., growth conditions). It outputs the identified causal relationships between entities in combination pairs. The output strictly follows the format: (Entity A, Entity B), (Entity C, Entity D) ... with no additional text."


for i, pdf_file in enumerate(pdf_files):
    pdf_path = os.path.join(pdf_directory, pdf_file)
    chunks = read_pdf_and_split_into_chunks(pdf_path)
    combined_response = ask_questions(chunks, questions, system_prompts)
    df = df.append({'PDF Title': pdf_file, 'Answer to Question 2': combined_response}, ignore_index=True)
    
    # Calculate and show the progress percentage
    progress = ((i + 1) / len(pdf_files)) * 100
    print(f"Processing '{pdf_file}': {progress:.2f}% completed")

import pandas as pd
import re

# Assuming `df` is your DataFrame

def sanitize_for_excel(value):
    """
    Sanitize a string value for Excel, removing illegal characters.
    """
    if isinstance(value, str):
        # Replace or remove illegal characters as necessary
        # Here, we simply remove them
        value = re.sub(r'[\x00-\x1f\x7f-\x9f]', '', value)
    return value

# Apply the sanitization function to every string value in the DataFrame
for col in df.columns:
    df[col] = df[col].apply(sanitize_for_excel)

# Now, try saving to Excel again
import pandas as pd
import re

# Assuming `df` is your DataFrame

def sanitize_for_excel(value):
    """
    Sanitize a string value for Excel, removing illegal characters.
    """
    if isinstance(value, str):
        # Replace or remove illegal characters as necessary
        # Here, we simply remove them
        value = re.sub(r'[\x00-\x1f\x7f-\x9f]', '', value)
    return value

# Apply the sanitization function to every string value in the DataFrame
for col in df.columns:
    df[col] = df[col].apply(sanitize_for_excel)

# Now, try saving to Excel again
output_file_path = 'updated(Qwen1.5 14b)Yarrowia_pdf_causal.xlsx'
df.to_excel(output_file_path, index=False)
# Out:
# Processing 'Importance of the methyl-citrate cycle on glycerol metabolism in the yeast Yarrowia lipolytica.pdf': 0.43% completed
# Processing 'Remodelling metabolism for high-level resveratrol production in Yarrowia lipolytica.pdf': 0.85% completed
# Processing 'Subunit composition of mitochondrial complex I from the yeast Yarrowia lipolytica.pdf': 1.28% completed
# Processing 'Efficient homologous recombination with short length flanking fragments in Ku70 deficient Yarrowia lipolytica strains.pdf': 1.71% completed
# Processing 'Engineering the Yeast Yarrowia lipolytica for Production of Polylactic Acid Homopolymer.pdf': 2.14% completed
# Processing 'Food-related applications of Yarrowia lipolytica.pdf': 2.56% completed
# Processing 'Production of plant natural products through engineered Yarrowia lipolytica.pdf': 2.99% completed
# Processing 'Targeting pathway expression to subcellular organelles improves astaxanthin synthesis in Yarrowia lipolytica.pdf': 3.42% completed
# Processing 'Yarrowia lipolytica recent achievements in heterologous protein expression and pathway engineering.pdf': 3.85% completed
# Processing 'Screening various Yarrowia lipolytica strains for citric acid production.pdf': 4.27% completed
# Processing 'Metabolic engineering for increased lipid accumulation in Yarrowia lipolytica – A Review.pdf': 4.70% completed
# Processing 'Engineering Yarrowia lipolytica for production of medium-chain fatty acids.pdf': 5.13% completed
# Processing 'Production of succinic acid at low pH by a recombinant strain of the aerobic yeast Yarrowia lipolytica.pdf': 5.56% completed
# Processing 'Engineering the oleaginous yeast Yarrowia lipolytica for high-level resveratrol production.pdf': 5.98% completed
# Processing 'Lipid production by the oleaginous yeast Yarrowia lipolytica using industrial by-products under different culture conditions.pdf': 6.41% completed
# Processing 'Yarrowia lipolytica as a workhorse for biofuel production.pdf': 6.84% completed
# Processing 'Biotechnological production of γ-decalactone, a peach like aroma, by Yarrowia lipolytica.pdf': 7.26% completed
# Processing 'Synthesis of α-ketoglutaric acid by Yarrowia lipolytica yeast grown on ethanol.pdf': 7.69% completed
# Processing 'New disruption cassettes for rapid gene disruption and marker rescue in the yeast Yarrowia lipolytica.pdf': 8.12% completed
# Processing 'The citric acid production from raw glycerol by Yarrowia lipolytica yeast and its regulation.pdf': 8.55% completed
# Processing 'Yarrowia lipolytica Growth Under Increased Air Pressure Influence on Enzyme Production.pdf': 8.97% completed
# Processing 'Production of Lycopene in the Non-Carotenoid-Producing Yeast Yarrowia lipolytica.pdf': 9.40% completed
# Processing 'Citric acid production by Yarrowia lipolytica cultivated on olive-mill wastewater-based media.pdf': 9.83% completed
# Processing 'Engineering Yarrowia lipolytica to produce advanced biofuels Current status and perspectives.pdf': 10.26% completed
# Processing 'Yarrowia lipolytica A model microorganism used for the production of tailor-made lipids.pdf': 10.68% completed
# Processing 'Synthetic Biology Expands the Industrial Potential of Yarrowia lipolytica.pdf': 11.11% completed
# Processing 'Improved campesterol production in engineered Yarrowia lipolytica strains.pdf': 11.54% completed
# Processing 's00253-022-11934-x.pdf': 11.97% completed
# Processing 'Metabolic Flexibility of Yarrowia lipolytica Growing on Glycerol.pdf': 12.39% completed
# Processing 'Lipid production by Yarrowia lipolytica growing on industrial glycerol in a single-stage continuous culture.pdf': 12.82% completed
# Processing 'Superoxide Radical Formation by Pure Complex I (NADHUbiquinone Oxidoreductase) from Yarrowia lipolytica.pdf': 13.25% completed
# Processing 'Sugar Alcohols and Organic Acids Synthesis in Yarrowia lipolytica Where Are We.pdf': 13.68% completed
# Processing 'Fermentation process for producing CFAs using Yarrowia lipolytica.pdf': 14.10% completed
# Processing 'Engineering Yarrowia lipolytica to enhance lipid production from lignocellulosic materials.pdf': 14.53% completed
# Processing 'Lipids by Yarrowia lipolytica Strains Cultivated on Glucose in Batch Cultures.pdf': 14.96% completed
# Processing 'Sustainable source of omega-3 eicosapentaenoic acid from metabolically engineered Yarrowia lipolytica from fundamental research to commercial production.pdf': 15.38% completed
# Processing 'Engineering of Yarrowia lipolytica for production of astaxanthin.pdf': 15.81% completed
# Processing 'Engineering the oleaginous yeast Yarrowia lipolytica for production of α-farnesene.pdf': 16.24% completed
# Processing 'Yarrowia lipolytica as a potential producer of citric acid.pdf': 16.67% completed
# Processing 'Characterization of Yarrowia lipolytica and related species for citric acid production from glycerol.pdf': 17.09% completed
# Processing 'A comprehensive assessment of Yarrowia lipolytica and its interactions with metals Current updates and future prospective.pdf': 17.52% completed
# Processing 'Regulation of Yeast-to-Hyphae Transition in Yarrowia lipolytica.pdf': 17.95% completed
# Processing 'Production of omega-3 eicosapentaenoic acid by metabolic engineering of Yarrowia lipolytica.pdf': 18.38% completed
# Processing 'Yarrowia lipolytica and Its Multiple Applications in the biotechnological industry.pdf': 18.80% completed
# Processing 'Multi-omics analysis reveals regulators of the response to nitrogen limitation in Yarrowia lipolytica.pdf': 19.23% completed
# Processing 'Isocitric acid production from rapeseed oil by Yarrowia lipolytica yeast.pdf': 19.66% completed
# Processing 'Park-2023-What-makes-yarrowia-lipolytica-well.pdf': 20.09% completed
# Processing 'Production and characterization of a bioemulsifier.pdf': 20.51% completed
# Processing 'Recovery and valorization of agri-food wastes and by-products using the non-conventional yeast Yarrowia lipolytica.pdf': 20.94% completed
# Processing 'Use of Non-Conventional Yeast Yarrowia lipolytica in Treatment or Upgradation of Hydrophobic Industry Wastes.pdf': 21.37% completed
# Processing 'Iterative integration of multiple-copy pathway genes in Yarrowia lipolytica for heterologous β-carotene production.pdf': 21.79% completed
# Processing 'Efficient conversion of crude glycerol from various industrial wastes into single cell oil by yeast Yarrowia lipolytica.pdf': 22.22% completed
# Processing 'Regulation of amino-acid metabolism controls flux to lipid accumulation in Yarrowia lipolytica.pdf': 22.65% completed
# Processing 'Lipid production in Yarrowia lipolytica is maximized by engineering cytosolic redox metabolism.pdf': 23.08% completed
# Processing 'Physiology and genetics of the dimorphic fungus Yarrowia lipolytica.pdf': 23.50% completed
# Processing 'Heterologous Protein Expression and Secretion in Yarrowia lipolytica.pdf': 23.93% completed
# Processing 'Factorial Design to Optimize Biosurfactant Production by Yarrowia lipolytica.pdf': 24.36% completed
# Processing 'Comparing cellular performance of Yarrowia lipolytica during growth on glucose and glycerol in submerged cultivations.pdf': 24.79% completed
# Processing 'Multiplex gene editing of the Yarrowia lipolytica genome using the CRISPR-Cas9 system.pdf': 25.21% completed
# Processing 'A novel application of solid state culture production of lipases by Yarrowia lipolytica.pdf': 25.64% completed
# Processing 'Engineering of a high lipid producing Yarrowia lipolytica strain.pdf': 26.07% completed
# Processing 'Sustainable Animal Feed Protein through the Cultivation of YARROWIA Lipolytica on Agro-Industrial Wastes and by-Products.pdf': 26.50% completed
# Processing 'Generalizing a hybrid synthetic promoter approach in Yarrowia lipolytica.pdf': 26.92% completed
# Processing 'Control of Lipid Accumulation in the Yeast Yarrowia lipolytica.pdf': 27.35% completed
# Processing 'Metabolic engineering of Yarrowia lipolytica for industrial applications.pdf': 27.78% completed
# Processing 'Sequence Assembly of Yarrowia lipolytica Strain W29CLIB89 Shows Transposable Element Diversity.pdf': 28.21% completed
# Processing 'Metabolic engineering for ricinoleic acid production in the oleaginous yeast Yarrowia lipolytica.pdf': 28.63% completed
# Processing 'Engineering the push and pull of lipid biosynthesis in oleaginous yeast Yarrowia lipolytica for biofuel production.pdf': 29.06% completed
# Processing 'Dimorphic transition in Yarrowia lipolytica isolated from oil-polluted sea water.pdf': 29.49% completed
# Processing 'Influence of Glucose and Saturated Free-Fatty Acid Mixtures on Citric Acid and Lipid Production by Yarrowia lipolytica.pdf': 29.91% completed
# Processing 'Metabolic engineering in the host Yarrowia lipolytica.pdf': 30.34% completed
# Processing 'Yarrowia lipolytica the novel and promising 2-phenylethanol producer.pdf': 30.77% completed
# Processing 'Enhancing isoprenoid synthesis in Yarrowia lipolytica by expressing the isopentenol utilization pathway and modulating intracellular hydrophobicity.pdf': 31.20% completed
# Processing 'Yarrowia lipolytica and pollutants Interactions and applications.pdf': 31.62% completed
# Processing 'Advances and opportunities in gene editing and gene regulation technology for Yarrowia lipolytica.pdf': 32.05% completed
# Processing 'Glycerol as a promising substrate for Yarrowia lipolytica biotechnological applications.pdf': 32.48% completed
# Processing 'Lipase from Yarrowia lipolytica Production, characterization and application as an industrial biocatalyst.pdf': 32.91% completed
# Processing 'Engineering 4-coumaroyl-CoA derived polyketide production in Yarrowia lipolytica through a β-oxidation mediated strategy.pdf': 33.33% completed
# Processing 'Improving the efficiency of homologous recombination by chemical and biological approaches in Yarrowia lipolytica.pdf': 33.76% completed
# Processing 'Yarrowia lipolytica a multitalented yeast species of.pdf': 34.19% completed
# Processing 'High-yield production of erythritol from raw glycerol in fed-batch cultures of Yarrowia lipolytica.pdf': 34.62% completed
# Processing 'Enhancing erythritol productivity in Yarrowia lipolytica using metabolic engineering.pdf': 35.04% completed
# Processing 'Biodegradation and utilization of waste cooking oil by Yarrowia lipolytica CECT 1240.pdf': 35.47% completed
# Processing 'Functional overexpression of genes involved in erythritol synthesis in the yeast Yarrowia lipolytica.pdf': 35.90% completed
# Processing 'Single cell oil production by Yarrowia lipolytica growing on an industrial derivative of animal fat in batch cultures.pdf': 36.32% completed
# Processing 'Engineering Yarrowia lipolytica to produce fuels and chemicals from xylose A review.pdf': 36.75% completed
# Processing 'Metabolic engineering of Yarrowia lipolytica to produce chemicals and fuels from xylose.pdf': 37.18% completed
# Processing 'Metabolic engineering of Yarrowia lipolytica for itaconic acid production.pdf': 37.61% completed
# Processing 'The complete mitochondrial genome of Yarrowia lipolytica.pdf': 38.03% completed
# Processing 'Approaches to improve the lipid synthesis of oleaginous yeast Yarrowia lipolytica A review.pdf': 38.46% completed
# Processing 'Metabolic activities of biotechnological interest in Yarrowia lipolytica grown on glycerol in repeated batch cultures.pdf': 38.89% completed
# Processing 'Synthetic biology tools for engineering Yarrowia lipolytica.pdf': 39.32% completed
# Processing 'Integrative transformation of the yeast Yarrowia lipolytica.pdf': 39.74% completed
# Processing 'Simultaneous production of citric acid and invertase by Yarrowia lipolytica SUC+ transformants.pdf': 40.17% completed
# Processing 'Citric acid production from sucrose using a recombinant strain of the yeast Yarrowia lipolytica.pdf': 40.60% completed
# Processing 'Advancing Yarrowia lipolytica as a superior biomanufacturing platform by tuning gene expression using promoter engineering.pdf': 41.03% completed
# Processing 'Advances in the metabolic engineering of Yarrowia lipolytica for the production of terpenoids.pdf': 41.45% completed
# Processing 'Utilization of an auxotrophic strain of the yeast Yarrowia lipolytica to improve γ-decalactone production yields.pdf': 41.88% completed
# Processing 'Optimization of lipid production with a genome-scale model of Yarrowia lipolytica.pdf': 42.31% completed
# Processing 'New inducible promoter for gene expression and synthetic biology in Yarrowia lipolytica.pdf': 42.74% completed
# Processing 'Enhanced lipid accumulation in the yeast Yarrowia lipolytica by over-expression of ATPcitrate lyase from Mus musculus.pdf': 43.16% completed
# Processing 'The role of Polyamine Metabolism in Dimorphism of Yarrowia Lipolytica.pdf': 43.59% completed
# Processing 'Engineering of Yarrowia lipolytica for terpenoid production.pdf': 44.02% completed
# Processing 'Yarrowia lipolytica A model and a tool to understand the mechanisms implicated in lipid accumulation.pdf': 44.44% completed
# Processing 'Snf1 Is a Regulator of Lipid Accumulation in Yarrowia lipolytica.pdf': 44.87% completed
# Processing '978-3-642-38583-4.pdf': 45.30% completed
# Processing 'High efficiency transformation by electroporation of Yarrowia lipolytica.pdf': 45.73% completed
# Processing 'Standardized Markerless Gene Integration for Pathway Engineering in Yarrowia lipolytica.pdf': 46.15% completed
# Processing 'Catabolism of hydroxyacids and biotechnological production of lactones by Yarrowia lipolytica.pdf': 46.58% completed
# Processing 'Polyol production from waste materials by genetically modified Yarrowia lipolytica.pdf': 47.01% completed
# Processing 'EasyCloneYALI CRISPRCas9-Based Synthetic Toolbox for Engineering of the Yeast Yarrowia lipolytica.pdf': 47.44% completed
# Processing 'Yarrowia lipolytica as a biotechnological chassis to produce usual and unusual fatty acids.pdf': 47.86% completed
# Processing 'Yarrowia lipolytica construction for heterologous synthesis of α-santalene and fermentation optimization.pdf': 48.29% completed
# Processing 'Factors Affecting the Morphogenetic Switch in Yarrowia lipolytica.pdf': 48.72% completed
# Processing 'Harnessing Yarrowia lipolytica lipogenesis to create a platform for lipid and biofuel production.pdf': 49.15% completed
# Processing 'Yarrowia lipolytica an industrial workhorse.pdf': 49.57% completed
# Processing 'Bioreactor-Scale Strategies for the Production of Recombinant Protein in the Yeast Yarrowia lipolytica.pdf': 50.00% completed
# Processing 'Tuning Gene Expression in Yarrowia lipolytica by a Hybrid Promoter Approach.pdf': 50.43% completed
# Processing 'Nitrogen as the major factor influencing gene expression in Yarrowia lipolytica.pdf': 50.85% completed
# Processing 'A synthetic biology approach to transform Yarrowia lipolytica into a competitive biotechnological producer of β-carotene.pdf': 51.28% completed
# Processing 'An evolutionary metabolic engineering approach for enhancing lipogenesis in Yarrowia lipolytica.pdf': 51.71% completed
# Processing 'Comparison of different strains of the yeastYarrowia lipolytica for citric acid production from glucose hydrol.pdf': 52.14% completed
# Processing 'Biosynthesis of lipids and organic acids by Yarrowia lipolytica strains cultivated on glucose.pdf': 52.56% completed
# Processing 'Droplet-based microfluidic high-throughput screening of heterologous enzymes secreted by the yeast Yarrowia lipolytica.pdf': 52.99% completed
# Processing 'Citric acid production from raw glycerol by acetate mutants of Yarrowia lipolytica.pdf': 53.42% completed
# Processing 'Biodegradation of oil wastewater by free and immobilized Yarrowia lipolytica W29.pdf': 53.85% completed
# Processing 'Biotechnological conversions of bio-diesel-derived crude glycerol by Yarrowia lipolytica strains.pdf': 54.27% completed
# Processing 'Holistic Approaches in Lipid Production by Yarrowia lipolytica.pdf': 54.70% completed
# Processing 'Genetic Control of Extracellular Protease Synthesis in the Yeast Yarrowia lipolytica.pdf': 55.13% completed
# Processing 'Enabling xylose utilization in Yarrowia lipolytica for lipid production.pdf': 55.56% completed
# Processing 'Rewiring Yarrowia lipolytica toward triacetic acid lactone for materials generation.pdf': 55.98% completed
# Processing 'Growth and neutral lipid synthesis by Yarrowia lipolytica on various carbon substrates under nutrient-sufficient and nutrient-limited conditions.pdf': 56.41% completed
# Processing 'Yarrowia lipolytica as a model for bio-oil production.pdf': 56.84% completed
# Processing 'Yarrowia lipolytica more than an oleaginous workhorse.pdf': 57.26% completed
# Processing 'Protein expression and secretion in the yeast Yarrowia lipolytica.pdf': 57.69% completed
# Processing 'Activating and Elucidating Metabolism of Complex Sugars in Yarrowia lipolytica.pdf': 58.12% completed
# Processing 'Isolation and characterization of two crude oil-degrading yeast strains, Yarrowia lipolytica PG-20 and PG-32, from the Persian Gulf.pdf': 58.55% completed
# Processing 'Bankar-2009-Environmental-and-industrial-applic.pdf': 58.97% completed
# Processing 'Overexpression of the ICL1 gene changes the product ratio of citric acid production by Yarrowia lipolytica.pdf': 59.40% completed
# Processing 'Renewable resources for biosurfactant production by yarrowia lipolytica.pdf': 59.83% completed
# Processing 'Engineering Yarrowia lipolytica for Campesterol Overproduction.pdf': 60.26% completed
# Processing 'Metabolic Engineering for Expanding the Substrate Range of Yarrowia lipolytica.pdf': 60.68% completed
# Processing 'Bioconversion of volatile fatty acids into lipids by the oleaginous yeast Yarrowia lipolytica.pdf': 61.11% completed
# Processing 'High-yield production of citric acid by Yarrowia lipolytica on glycerol in repeated-batch bioreactors.pdf': 61.54% completed
# Processing 'A novel strain of Yarrowia lipolytica as a platform for value-added product synthesis from glycerol.pdf': 61.97% completed
# Processing 'Integrated knowledge mining, genome-scale modeling, and machine learning for predicting Yarrowia lipolytica bioproduction.pdf': 62.39% completed
# Processing 'Morphological analysis of Yarrowia lipolytica under stress conditions through image processing.pdf': 62.82% completed
# Processing 'Overlapping Reading Frames at the LYS5 Locus in the Yeast Yarrowia lipolytica.pdf': 63.25% completed
# Processing 'Enhanced α-ketoglutaric acid production in Yarrowia lipolytica WSH-Z06 by an improved integrated fed-batch strategy.pdf': 63.68% completed
# Processing 'Two upstream activation sequences control the expression of the XPR2 gene in the yeast Yarrowia lipolytica.pdf': 64.10% completed
# Processing 'Impacts of environmental conditions on product formation and morphology of Yarrowia lipolytica.pdf': 64.53% completed
# Processing 'A modular Golden Gate toolkit for Yarrowia lipolytica synthetic biology.pdf': 64.96% completed
# Processing 'Oxygen requirements for growth and citric acid production of Yarrowia lipolytica.pdf': 65.38% completed
# Processing 'Identification of genome integration sites for developing a CRISPR-based gene expression toolkit in Yarrowia lipolytica.pdf': 65.81% completed
# Processing 'Harnessing Yarrowia lipolytica Peroxisomes as a Subcellular Factory for α-Humulene Overproduction.pdf': 66.24% completed
# Processing 'Engineering Yarrowia lipolytica as a platform for synthesis of drop-in transportation fuels and oleochemicals.pdf': 66.67% completed
# Processing 'A new recombinant protein expression system for high-throughput screening in the yeast Yarrowia lipolytica.pdf': 67.09% completed
# Processing 'Accumulation of a Cocoa-Butter-Like Lipid by Yarrowia lipolytica Cultivated on Agro-Industrial Residues.pdf': 67.52% completed
# Processing 'A molecular genetic toolbox for Yarrowia lipolytica.pdf': 67.95% completed
# Processing 'Metabolic engineering of Yarrowia lipolytica for improving squalene production.pdf': 68.38% completed
# Processing 'Characterization of erythrose reductase from Yarrowia lipolytica and its influence on erythritol synthesis.pdf': 68.80% completed
# Processing 'Multiple-copy integration in the yeast Yarrowia lipolytica.pdf': 69.23% completed
# Processing 'Oil Production from Yarrowia lipolytica Po1g Using Rice Bran Hydrolysate.pdf': 69.66% completed
# Processing 'Proteolytic, lipolytic and molecular characterisation of Yarrowia lipolytica isolated from cheese.pdf': 70.09% completed
# Processing 'Tolerance of Yarrowia lipolytica to inhibitors commonly found in lignocellulosic hydrolysates.pdf': 70.51% completed
# Processing 'The oxidative pentose phosphate pathway is the primary source of NADPH for lipid overproduction from glucose in Yarrowia lipolytica.pdf': 70.94% completed
# Processing 'Advanced Strategies for the Synthesis of Terpenoids in Yarrowia lipolytica.pdf': 71.37% completed
# Processing 'High lipid accumulation in Yarrowia lipolytica cultivated under double limitation of nitrogen and magnesium.pdf': 71.79% completed
# Processing 'Heterologous production of α-farnesene in metabolically engineered strains of Yarrowia lipolytica.pdf': 72.22% completed
# Processing 'Optimization of Citric Acid Production from Glucose by Yarrowia lipolytica.pdf': 72.65% completed
# Processing 'Engineering Promoter Architecture in Oleaginous Yeast Yarrowia lipolytica.pdf': 73.08% completed
# Processing 'Production of α-linolenic acid in Yarrowia lipolytica using low-temperature fermentation.pdf': 73.50% completed
# Processing 'Yarrowia lipolytica as an Alternative and Valuable Source of Nutritional and Bioactive Compounds for Humans.pdf': 73.93% completed
# Processing 'A genome-scale metabolic model of the lipid-accumulating yeast Yarrowia lipolytica.pdf': 74.36% completed
# Processing 'Functional analysis of upstream regulating regions from the Yarrowia lipolytica XPR2 promoter.pdf': 74.79% completed
# Processing 'A molecular approach to optimize hIFN α2b expression and secretion in Yarrowia lipolytica.pdf': 75.21% completed
# Processing 'Heterologous protein expression and secretion in the non-conventional yeast Yarrowia lipolytica a review.pdf': 75.64% completed
# Processing 'Kinetic profile of the cellular lipid composition in an oleaginous Yarrowia lipolytica capable of producing a cocoa-butter substitute from industrial fats.pdf': 76.07% completed
# Processing 'Biodiesel production from lignocellulosic biomass using Yarrowia lipolytica.pdf': 76.50% completed
# Processing 'Heavy metal tolerance in marine strains of Yarrowia lipolytica.pdf': 76.92% completed
# Processing 'Metabolic engineering of Yarrowia lipolytica for terpenoids production advances and perspectives.pdf': 77.35% completed
# Processing 'Cloning of the LYS5 gene encoding saccharopine dehydrogenase from the yeast Yarrowia lipolytica by target integration.pdf': 77.78% completed
# Processing 'Role of β-Oxidation Enzymes in γ-Decalactone Production by the Yeast Yarrowia lipolytica.pdf': 78.21% completed
# Processing 'Alternative Substrate Metabolism in Yarrowia lipolytica.pdf': 78.63% completed
# Processing 'Enhancing linalool production by engineering oleaginous yeast Yarrowia lipolytica.pdf': 79.06% completed
# Processing 'Variability of the lipolytic activity in Yarrowia lipolytica and its dependence on environmental conditions.pdf': 79.49% completed
# Processing 'Advancing metabolic engineering of Yarrowia lipolytica using the CRISPRCas system.pdf': 79.91% completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e2f422132575> in <module>
#      62     pdf_path = os.path.join(pdf_directory, pdf_file)
#      63     chunks = read_pdf_and_split_into_chunks(pdf_path)
# ---> 64     combined_response = ask_questions(chunks, questions, system_prompts)
#      65     df = df.append({'PDF Title': pdf_file, 'Combined Response': combined_response}, ignore_index=True)
#      66
#
# <ipython-input-2-e2f422132575> in ask_questions(chunks, question, system_prompt)
#      33         model_inputs = tokenizer([text], return_tensors="pt").to(device)
#      34
# ---> 35         generated_ids = model.generate(
#      36             model_inputs.input_ids,
#      37             max_new_tokens=5000
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1518
#    1519             # 13. run sample
# -> 1520             return self.sample(
#    1521                 input_ids,
#    1522                 logits_processor=prepared_logits_processor,
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/transformers/generation/utils.py in sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2651             # sample
#    2652             probs = nn.functional.softmax(next_token_scores, dim=-1)
# -> 2653             next_tokens = torch.multinomial(probs, num_samples=1).squeeze(1)
#    2654
#    2655             # finished sentences should have their next token be a padding token
#
# KeyboardInterrupt:
